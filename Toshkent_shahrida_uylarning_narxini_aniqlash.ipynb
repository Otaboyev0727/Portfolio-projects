# %% [markdown]
# <a href="https://colab.research.google.com/github/Otaboyev0727/Loyihalar/blob/main/Toshkent_shahrida_uylarning_narxini_aniqlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Portfolio uchun vazifa: Toshkent shahrida uylarning narxini aniqlash.
#
# Ushbu amaliyotda  berilgan ma`lumotlar asosida Toshkent shahridagi uylarning narxini aniqlash.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_data_08-02-2021.csv')
df.head()
# Out:
#                                             location       district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...   Юнусабадский      3
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  Яккасарайский      2
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...   Чиланзарский      2
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...   Чиланзарский      3
# 4  город Ташкент, Чиланзарский район, площадь Актепа   Чиланзарский      3
#
#   size  level  max_levels  price
# 0   57      4           4  52000
# 1   52      4           5  56000
# 2   42      4           4  37000
# 3   65      1           4  49500
# 4   70      3           5  55000

# %% [markdown]
# # Ustunlar ta'rifi
# - `location` - sotilayotgan uy manzili
# - `district` - uy joylashgan tuman
# - `rooms` - xonalar soni
# - `size` - uy maydoni (kv.m)
# - `level` - uy joylashgan qavat
# - `max_levels` - ja'mi qavatlar soni
# - `price` - uy narxi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7254 entries, 0 to 7564
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    7254 non-null   object
#  1   district    7254 non-null   object
#  2   rooms       7254 non-null   int64
#  3   size        7254 non-null   float64
#  4   level       7254 non-null   int64
#  5   max_levels  7254 non-null   int64
#  6   price       7254 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 453.4+ KB

# %%
df.describe()
# Out:
#              rooms         size        level   max_levels          price
# count  7254.000000  7254.000000  7254.000000  7254.000000    7254.000000
# mean      2.576096    69.984924     3.693962     6.000276   54002.840915
# std       1.026701    28.597803     2.236610     2.598083   29193.228768
# min       1.000000    15.000000     1.000000     1.000000    8500.000000
# 25%       2.000000    50.000000     2.000000     4.000000   34825.000000
# 50%       2.000000    65.000000     3.000000     5.000000   45500.000000
# 75%       3.000000    83.000000     5.000000     9.000000   65000.000000
# max       8.000000   246.000000    19.000000    25.000000  198000.000000

# %%
df[df['size']<=250][df['size']>=15]
# Out:
# <ipython-input-25-191979e4dc23>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['size']<=250][df['size']>=15]
#                                                location           district  \
# 0     город Ташкент, Юнусабадский район, Юнусабад 8-...       Юнусабадский
# 1     город Ташкент, Яккасарайский район, 1-й тупик ...      Яккасарайский
# 2     город Ташкент, Чиланзарский район, Чиланзар 2-...       Чиланзарский
# 3     город Ташкент, Чиланзарский район, Чиланзар 9-...       Чиланзарский
# 4     город Ташкент, Чиланзарский район, площадь Актепа       Чиланзарский
# ...                                                 ...                ...
# 7560  город Ташкент, Яшнободский район, Городок Авиа...        Яшнободский
# 7561  город Ташкент, Яшнободский район, 1-й проезд А...        Яшнободский
# 7562  город Ташкент, Шайхантахурский район, Зульфиях...    Шайхантахурский
# ...

# %%
df=df[df['size']<=250][df['size']>=15]
# Out:
# <ipython-input-26-00f65c7229b9>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df=df[df['size']<=250][df['size']>=15]

# %%
df=df[df['price']<200000][df['price']>=8000]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='size', y='price')
plt.show()

# %%
df['district'].value_counts()
# Out:
# Чиланзарский         1616
# Мирзо-Улугбекский    1339
# Учтепинский           870
# Юнусабадский          844
# Мирабадский           710
# Яккасарайский         622
# Яшнободский           453
# Шайхантахурский       358
# Олмазорский           262
# Сергелийский          158
# Янгихаётский           14
# Бектемирский            8
# Name: district, dtype: int64

# %%
df.price
# Out:
# 0       52000
# 1       56000
# 2       37000
# 3       49500
# 4       55000
#         ...
# 7560    24500
# 7561    32000
# 7562    40000
# 7563    11000
# 7564    22914
# Name: price, Length: 7565, dtype: object

# %%
dogovor=df[df.price=='Договорная']

# %%
len(df['size']=='Площадьземли:1сот')
# Out:
# 7565

# %%
sizenul=df[df['size']=='Площадьземли:1сот']

# %%
df.drop(dogovor.index,inplace=True)

# %%
df.drop(sizenul.index,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7254 entries, 0 to 7564
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    7254 non-null   object
#  1   district    7254 non-null   object
#  2   rooms       7254 non-null   int64
#  3   size        7254 non-null   float64
#  4   level       7254 non-null   int64
#  5   max_levels  7254 non-null   int64
#  6   price       7254 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 453.4+ KB

# %%
df['size'] = df['size'].astype(float)
df['price'] = df['price'].astype(float)

# %%
df.corrwith(df['price'],)
# Out:
# rooms         0.606495
# size          0.787382
# level         0.083700
# max_levels    0.265283
# price         1.000000
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
cols = ['rooms','size','level','price','max_levels']
sns.pairplot(df[cols], height=5)
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(data=df,x=df["size"],y=df.price)
plt.show()

# %%
df.head()
# Out:
#                                             location       district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...   Юнусабадский      3
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  Яккасарайский      2
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...   Чиланзарский      2
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...   Чиланзарский      3
# 4  город Ташкент, Чиланзарский район, площадь Актепа   Чиланзарский      3
#
#    size  level  max_levels    price
# 0  57.0      4           4  52000.0
# 1  52.0      4           5  56000.0
# 2  42.0      4           4  37000.0
# 3  65.0      1           4  49500.0
# 4  70.0      3           5  55000.0

# %%
df['rooms_size'] = df['size']/df['rooms']
df["size_level"] = df["size"]/df["level"]
df["avarege_level"]=df["level"]/df["max_levels"]

# %%
df.sample(7)
# Out:
#                                                location           district  \
# 656   город Ташкент, Учтепинский район, Чиланзар 31-...        Учтепинский
# 1729      город Ташкент, Шайхантахурский район, Богкуча    Шайхантахурский
# 5085  город Ташкент, Чиланзарский район, Чиланзар 3-...       Чиланзарский
# 2141    город Ташкент, Мирзо-Улугбекский район, Паркент  Мирзо-Улугбекский
# 2790  город Ташкент, Учтепинский район, Чиланзар 31-...        Учтепинский
# 925          город Ташкент, Учтепинский район, Гулистон        Учтепинский
# 3220  город Ташкент, Мирзо-Улугбекский район, Буюк И...  Мирзо-Улугбекский
#
#       rooms  size  level  max_levels    price  rooms_size  size_level  \
# 656       4  98.0      1           9  85000.0   24.500000   98.000000
# 1729      5  96.0      1           5  75000.0   19.200000   96.000000
# 5085      1  30.0      1           4  25000.0   30.000000   30.000000
# 2141      3  80.0      7           8  70000.0   26.666667   11.428571
# ...

# %%
df.corrwith(df['price']).sort_values(ascending=False)
# Out:
# price            1.000000
# size             0.787382
# rooms            0.606495
# size_level       0.380477
# max_levels       0.265283
# rooms_size       0.172902
# level            0.083700
# avarege_level   -0.130473
# dtype: float64

# %%
df=df.drop("location",axis=1)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

X_train = train_set.drop("price", axis=1)
y = train_set["price"].copy()

X_num = X_train.drop("district", axis=1)

# %%
from sklearn.base import BaseEstimator, TransformerMixin
# bizga kerak ustunlar indekslari
rooms_ix, size_ix, level_ix, maxlevels_ix = 1, 2, 3, 4

class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room = True):
        self.add_bedrooms_per_room = add_bedrooms_per_room
    def fit(self, X, y=None):
        return self # bizni funksiyamiz faqat transformer. estimator emas
    def transform(self, X):
        rooms_per_household = X[:, rooms_ix] / X[:, households_ix]
        population_per_household = X[:, population_ix] / X[:, households_ix]
        if self.add_bedrooms_per_room: # add_bedrooms_per_room ustuni ixtiyoriy bo'ladi
            bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
            return np.c_[X, rooms_per_household, population_per_household, bedrooms_per_room]
        else:
            return np.c_[X, rooms_per_household, population_per_household]

# %%
df['rooms_size'] = df['size']/df['rooms']
df["size_level"] = df["size"]/df["level"]
df["avarege_level"]=df["level"]/df["max_levels"]

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

num_pipeline = Pipeline([
          ('imputer', SimpleImputer(strategy='median')),
        
          ('std_scaler', StandardScaler())             
])

# %%
from sklearn.compose import ColumnTransformer
import numpy as np

num_attribs = list(X_num)
cat_attribs = ['district']

full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', OneHotEncoder(), cat_attribs)
])

# %%
X_prepared = full_pipeline.fit_transform(X_train)

# %%
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()

# %%
LR_model.fit(X_prepared, y)
# Out:
# LinearRegression()

# %%
X_test = test_set.drop('price', axis=1)
X_test
# Out:
#              district  rooms    size  level  max_levels  rooms_size  \
# 3075      Мирабадский      3  120.00     10          10   40.000000
# 1755    Яккасарайский      4  104.00      4           5   26.000000
# 4113      Олмазорский      4   86.00      4           5   21.500000
# 6626      Олмазорский      1   40.52      4           4   40.520000
# 7436      Учтепинский      2   42.16      1           1   21.080000
# ...               ...    ...     ...    ...         ...         ...
# 6215     Чиланзарский      1   40.00      1           4   40.000000
# 4984      Яшнободский      1   20.00      2           4   20.000000
# 6100     Чиланзарский      3   65.00      4           4   21.666667
# 5056      Мирабадский      2   53.00      6          10   26.500000
# 6531  Шайхантахурский      3   68.37      2           9   22.790000
#
#       size_level  avarege_level
# 3075   12.000000       1.000000
# 1755   26.000000       0.800000
# 4113   21.500000       0.800000
# ...

# %%
y_test = test_set['price'].copy()
y_test
# Out:
# 3075    118000.0
# 1755     78500.0
# 4113     40000.0
# 6626     23000.0
# 7436     29000.0
#           ...
# 6215     27500.0
# 4984     14000.0
# 6100     43500.0
# 5056     74200.0
# 6531     56000.0
# Name: price, Length: 1451, dtype: float64

# %%
X_test_prepared = full_pipeline.transform(X_test)

# %%
y_predicted = LR_model.predict(X_test_prepared)
y_predicted
# Out:
# array([102466.47353047,  83041.82273907,  51258.30495599, ...,
#         43692.88781983,  53966.24250625,  58373.2293862 ])

# %%
from sklearn.metrics import mean_squared_error
lin_mse = mean_squared_error(y_test, y_predicted)
# RMSE hisoblaymiz
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 16827.94958379447

# %%
from sklearn.tree import DecisionTreeRegressor
Tree_model = DecisionTreeRegressor()
Tree_model.fit(X_prepared, y)
# Out:
# DecisionTreeRegressor()

# %%
y_predicted = Tree_model.predict(X_test_prepared)

# %%
lin_mse = mean_squared_error(y_test, y_predicted)
# RMSE hisoblaymiz
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 18354.738091226212

# %%
from sklearn.ensemble import RandomForestRegressor
RF_model = RandomForestRegressor()
RF_model.fit(X_prepared, y)
# Out:
# RandomForestRegressor()

# %%
y_predicted = RF_model.predict(X_test_prepared)
lin_mse = mean_squared_error(y_test, y_predicted)
# RMSE hisoblaymiz
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 14061.581433769166

# %%
X = df.drop("price", axis=1)
y = df["price"].copy()

X_prepared = full_pipeline.transform(X)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Std.dev:", scores.std())

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(LR_model, X_prepared, y, scoring="neg_mean_squared_error", cv=10)
LR_rmse_scores = np.sqrt(-scores)

# %%
display_scores(LR_rmse_scores)
# Out:
# Scores: [14607.10679249 15312.43051265 17996.79712476 18343.90801777
#  18316.21860611 19094.97873966 15135.5027841  14510.43526068
#  16808.23334021 15459.71938445]
# Mean: 16558.533056288463
# Std.dev: 1662.2117779016776

# %%
df.to_csv('housing_LR.csv')
